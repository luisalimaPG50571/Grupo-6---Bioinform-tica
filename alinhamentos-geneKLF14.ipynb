# %%
from Bio.Blast import NCBIXML
from Bio.Blast import NCBIWWW
from Bio import SeqIO

# %%
seq_KLF14 = SeqIO.read(open("KLF14.fasta"), format="fasta")
print (len(seq_KLF14.seq))
# Out:
# 3511

# %%
# realizar o blast com a sequencia do gene 
# registar o resultado num ficheiro formato .xml

result_handle = NCBIWWW.qblast("blastn", "nt", seq_KLF14.format("fasta"))
file_save = open ("my_blast_KLF14.xml", "w")
file_save.write(result_handle.read())
file_save.close()
result_handle.close()

# %%
result_handle = open("my_blast_KLF14.xml")
record = NCBIXML.read(result_handle)

# %%
print("Parâmetros")
print("Database:" , record.database)
print("Matrix:", record.matrix)
print("Gap penalties:", record.gap_penalties)
# Out:
# Parâmetros
# Database: nt
# Matrix:
# Gap penalties: (5, 2)

# %%
e_value_threshold = 0.0000001
c = len(seq_KLF14.seq)

print("Sequências homólogas:")
print("")
for alignment in record.alignments:
    for hsp in alignment.hsps:
        n=hsp.align_length
        i=(hsp.identities/n)
        q=(n/c)
        p=(hsp.positives/n)
        if hsp.expect < e_value_threshold:
            print("Acesso:" , alignment.accession)
            print("Hit id:" , alignment.hit_id)
            print("E-value:" , hsp.expect)
            print("Comprimento:", hsp.align_length)
            print("Identidade:" , (i*100), "%")
            print("Query cover:" , (q*100), "%")
            print("Positivies:", (p*100), "%")
            print("Definição:" ,alignment.hit_def)
            print("---Alinhamento----", "Query start:", hsp.query_start, "Sbjct start:",hsp.sbjct_start)
            print("")
# Out:
# Sequências homólogas:
#
# Acesso: NM_138693
# Hit id: gi|1821955883|ref|NM_138693.4|
# E-value: 0.0
# Comprimento: 3511
# Identidade: 100.0 %
# Query cover: 100.0 %
# Positivies: 100.0 %
# Definição: Homo sapiens KLF transcription factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 1 Sbjct start: 1
#
# Acesso: NG_016152
# Hit id: gi|1958130113|ref|NG_016152.3|
# E-value: 0.0
# Comprimento: 3511
# Identidade: 100.0 %
# Query cover: 100.0 %
# Positivies: 100.0 %
# Definição: Homo sapiens KLF transcription factor 14 (KLF14), RefSeqGene (LRG_1039) on chromosome 7
# ---Alinhamento---- Query start: 1 Sbjct start: 5001
#
# Acesso: AC234644
# Hit id: gi|223468741|gb|AC234644.1|
# E-value: 0.0
# Comprimento: 3511
# Identidade: 100.0 %
# Query cover: 100.0 %
# Positivies: 100.0 %
# Definição: Homo sapiens BAC clone RP11-303K3 from chromosome 7, complete sequence
# ---Alinhamento---- Query start: 1 Sbjct start: 12752
#
# Acesso: AC187610
# Hit id: gi|145699327|gb|AC187610.3|
# E-value: 0.0
# Comprimento: 3507
# Identidade: 99.23011120615911 %
# Query cover: 99.88607234406152 %
# Positivies: 99.23011120615911 %
# Definição: Pan troglodytes BAC clone CH251-661M24 from chromosome 7, complete sequence
# ---Alinhamento---- Query start: 5 Sbjct start: 180721
#
# Acesso: AC009274
# Hit id: gi|21217400|gb|AC009274.11|
# E-value: 0.0
# Comprimento: 3365
# Identidade: 99.73254086181278 %
# Query cover: 95.84164055824552 %
# Positivies: 99.73254086181278 %
# Definição: Homo sapiens chromosome 7 clone RP11-254L11, complete sequence
# ---Alinhamento---- Query start: 147 Sbjct start: 114349
#
# Acesso: AC009274
# Hit id: gi|21217400|gb|AC009274.11|
# E-value: 1.02024e-31
# Comprimento: 100
# Identidade: 94.0 %
# Query cover: 2.8481913984619767 %
# Positivies: 94.0 %
# Definição: Homo sapiens chromosome 7 clone RP11-254L11, complete sequence
# ---Alinhamento---- Query start: 1 Sbjct start: 114428
#
# Acesso: XM_050782505
# Hit id: gi|2309459600|ref|XM_050782505.1|
# E-value: 0.0
# Comprimento: 3511
# Identidade: 95.8131586442609 %
# Query cover: 100.0 %
# Positivies: 95.8131586442609 %
# Definição: PREDICTED: Macaca thibetana thibetana KLF transcription factor 14 (LOC126949725), mRNA
# ---Alinhamento---- Query start: 1 Sbjct start: 1
#
# Acesso: XM_003896608
# Hit id: gi|1220208198|ref|XM_003896608.4|
# E-value: 0.0
# Comprimento: 3439
# Identidade: 96.30706600756034 %
# Query cover: 97.94930219310739 %
# Positivies: 96.30706600756034 %
# Definição: PREDICTED: Papio anubis Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 69 Sbjct start: 1
#
# Acesso: XM_015134908
# Hit id: gi|1622919941|ref|XM_015134908.2|
# E-value: 0.0
# Comprimento: 3403
# Identidade: 96.23861298853953 %
# Query cover: 96.92395328966107 %
# Positivies: 96.23861298853953 %
# Definição: PREDICTED: Macaca mulatta Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 109 Sbjct start: 3
#
# Acesso: XM_012088095
# Hit id: gi|795403252|ref|XM_012088095.1|
# E-value: 0.0
# Comprimento: 3338
# Identidade: 96.28520071899341 %
# Query cover: 95.07262888066079 %
# Positivies: 96.28520071899341 %
# Definição: PREDICTED: Cercocebus atys Kruppel-like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_024131928
# Hit id: gi|1595762478|ref|XM_024131928.2|
# E-value: 0.0
# Comprimento: 3514
# Identidade: 82.84006829823562 %
# Query cover: 100.08544574195386 %
# Positivies: 82.84006829823562 %
# Definição: PREDICTED: Physeter catodon Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 2 Sbjct start: 63
#
# Acesso: XM_032484379
# Hit id: gi|1811071878|ref|XM_032484379.1|
# E-value: 0.0
# Comprimento: 3513
# Identidade: 82.66438941076004 %
# Query cover: 100.05696382796924 %
# Positivies: 82.66438941076004 %
# Definição: PREDICTED: Camelus ferus Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 1 Sbjct start: 83
#
# Acesso: XM_033863276
# Hit id: gi|1835253206|ref|XM_033863276.1|
# E-value: 0.0
# Comprimento: 3549
# Identidade: 82.36122851507467 %
# Query cover: 101.08231273141554 %
# Positivies: 82.36122851507467 %
# Definição: PREDICTED: Tursiops truncatus Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 8 Sbjct start: 219
#
# Acesso: XM_036078243
# Hit id: gi|1899970704|ref|XM_036078243.1|
# E-value: 0.0
# Comprimento: 3538
# Identidade: 82.3911814584511 %
# Query cover: 100.76901167758474 %
# Positivies: 82.3911814584511 %
# Definição: PREDICTED: Halichoerus grypus Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 35 Sbjct start: 1
#
# Acesso: XM_027101909
# Hit id: gi|1516086623|ref|XM_027101909.1|
# E-value: 0.0
# Comprimento: 3554
# Identidade: 82.27349465391109 %
# Query cover: 101.22472230133866 %
# Positivies: 82.27349465391109 %
# Definição: PREDICTED: Lagenorhynchus obliquidens Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 3 Sbjct start: 51
#
# Acesso: XM_030853833
# Hit id: gi|1746169887|ref|XM_030853833.1|
# E-value: 0.0
# Comprimento: 3515
# Identidade: 82.33285917496444 %
# Query cover: 100.11392765593847 %
# Positivies: 82.33285917496444 %
# Definição: PREDICTED: Globicephala melas Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 42 Sbjct start: 1
#
# Acesso: XM_004272188
# Hit id: gi|2280724715|ref|XM_004272188.4|
# E-value: 0.0
# Comprimento: 3544
# Identidade: 81.941309255079 %
# Query cover: 100.93990316149247 %
# Positivies: 81.941309255079 %
# Definição: PREDICTED: Orcinus orca KLF transcription factor 14 (LOC101270875), mRNA
# ---Alinhamento---- Query start: 17 Sbjct start: 2020
#
# Acesso: XM_004741996
# Hit id: gi|2130915547|ref|XM_004741996.3|
# E-value: 0.0
# Comprimento: 3525
# Identidade: 81.61702127659575 %
# Query cover: 100.39874679578466 %
# Positivies: 81.61702127659575 %
# Definição: PREDICTED: Mustela putorius furo Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 26 Sbjct start: 90
#
# Acesso: CP071569
# Hit id: gi|2023428935|gb|CP071569.1|
# E-value: 0.0
# Comprimento: 3571
# Identidade: 80.84570148417811 %
# Query cover: 101.70891483907718 %
# Positivies: 80.84570148417811 %
# Definição: Sus scrofa scrofa breed NS chromosome 18
# ---Alinhamento---- Query start: 5 Sbjct start: 18707764
#
# Acesso: XM_043590472
# Hit id: gi|2092002484|ref|XM_043590472.1|
# E-value: 0.0
# Comprimento: 3393
# Identidade: 81.07869142351902 %
# Query cover: 96.63913414981486 %
# Positivies: 81.07869142351902 %
# Definição: PREDICTED: Prionailurus bengalensis Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_040471943
# Hit id: gi|2020749753|ref|XM_040471943.1|
# E-value: 0.0
# Comprimento: 3413
# Identidade: 80.925871667155 %
# Query cover: 97.20877242950726 %
# Positivies: 80.925871667155 %
# Definição: PREDICTED: Puma yagouaroundi Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_027075494
# Hit id: gi|1512020456|ref|XM_027075494.1|
# E-value: 0.0
# Comprimento: 3395
# Identidade: 81.03092783505154 %
# Query cover: 96.6960979777841 %
# Positivies: 81.03092783505154 %
# Definição: PREDICTED: Acinonyx jubatus Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_019452767
# Hit id: gi|1111142517|ref|XM_019452767.1|
# E-value: 0.0
# Comprimento: 3396
# Identidade: 81.00706713780919 %
# Query cover: 96.72457989176873 %
# Positivies: 81.00706713780919 %
# Definição: PREDICTED: Panthera pardus Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_045497102
# Hit id: gi|2166764413|ref|XM_045497102.1|
# E-value: 0.0
# Comprimento: 3397
# Identidade: 80.98322048866648 %
# Query cover: 96.75306180575335 %
# Positivies: 80.98322048866648 %
# Definição: PREDICTED: Leopardus geoffroyi Kruppel like factor 14 (KLF14), transcript variant X1, mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_023250574
# Hit id: gi|1304888989|ref|XM_023250574.1|
# E-value: 0.0
# Comprimento: 3395
# Identidade: 80.91310751104565 %
# Query cover: 96.6960979777841 %
# Positivies: 80.91310751104565 %
# Definição: PREDICTED: Felis catus Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_032305912
# Hit id: gi|1804792636|ref|XM_032305912.1|
# E-value: 0.0
# Comprimento: 3170
# Identidade: 82.11356466876971 %
# Query cover: 90.28766733124466 %
# Positivies: 82.11356466876971 %
# Definição: PREDICTED: Mustela erminea Kruppel like factor 14 (KLF14), transcript variant X4, mRNA
# ---Alinhamento---- Query start: 98 Sbjct start: 1
#
# Acesso: XM_025291541
# Hit id: gi|2148426095|ref|XM_025291541.3|
# E-value: 0.0
# Comprimento: 3479
# Identidade: 79.33314170738718 %
# Query cover: 99.08857875249217 %
# Positivies: 79.33314170738718 %
# Definição: PREDICTED: Bubalus bubalis Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 70 Sbjct start: 1
#
# Acesso: XM_027538972
# Hit id: gi|1542945803|ref|XM_027538972.1|
# E-value: 0.0
# Comprimento: 3489
# Identidade: 79.04843794783606 %
# Query cover: 99.37339789233836 %
# Positivies: 79.04843794783606 %
# Definição: PREDICTED: Bos indicus x Bos taurus Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 94 Sbjct start: 8
#
# Acesso: XM_003845968
# Hit id: gi|1849170902|ref|XM_003845968.4|
# E-value: 0.0
# Comprimento: 1623
# Identidade: 99.38385705483672 %
# Query cover: 46.22614639703788 %
# Positivies: 99.38385705483672 %
# Definição: PREDICTED: Pan paniscus Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 16 Sbjct start: 1
#
# Acesso: XM_003318801
# Hit id: gi|1034063511|ref|XM_003318801.3|
# E-value: 0.0
# Comprimento: 1571
# Identidade: 99.55442393380012 %
# Query cover: 44.74508686983765 %
# Positivies: 99.55442393380012 %
# Definição: PREDICTED: Pan troglodytes Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 70 Sbjct start: 1
#
# Acesso: XM_007982949
# Hit id: gi|1938861275|ref|XM_007982949.2|
# E-value: 0.0
# Comprimento: 1640
# Identidade: 96.52439024390243 %
# Query cover: 46.710338934776416 %
# Positivies: 96.52439024390243 %
# Definição: PREDICTED: Chlorocebus sabaeus Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 1 Sbjct start: 177
#
# Acesso: XM_033192897
# Hit id: gi|1825929198|ref|XM_033192897.1|
# E-value: 0.0
# Comprimento: 1636
# Identidade: 96.33251833740832 %
# Query cover: 46.59641127883794 %
# Positivies: 96.33251833740832 %
# Definição: PREDICTED: Trachypithecus francoisi Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 8 Sbjct start: 37
#
# Acesso: XM_005550797
# Hit id: gi|2161896150|ref|XM_005550797.3|
# E-value: 0.0
# Comprimento: 1609
# Identidade: 96.76817899316346 %
# Query cover: 45.827399601253205 %
# Positivies: 96.76817899316346 %
# Definição: PREDICTED: Macaca fascicularis Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 32 Sbjct start: 1
#
# Acesso: XM_036909005
# Hit id: gi|1920325892|ref|XM_036909005.1|
# E-value: 0.0
# Comprimento: 2494
# Identidade: 83.84121892542102 %
# Query cover: 71.0338934776417 %
# Positivies: 83.84121892542102 %
# Definição: PREDICTED: Manis pentadactyla Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 45 Sbjct start: 3
#
# Acesso: XM_031013429
# Hit id: gi|1753082652|ref|XM_031013429.1|
# E-value: 0.0
# Comprimento: 1474
# Identidade: 99.4572591587517 %
# Query cover: 41.98234121332954 %
# Positivies: 99.4572591587517 %
# Definição: PREDICTED: Gorilla gorilla gorilla Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_030933238
# Hit id: gi|1751286530|ref|XM_030933238.1|
# E-value: 0.0
# Comprimento: 1610
# Identidade: 95.527950310559 %
# Query cover: 45.855881515237826 %
# Positivies: 95.527950310559 %
# Definição: PREDICTED: Rhinopithecus roxellana Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 45 Sbjct start: 2
#
# Acesso: XM_003261343
# Hit id: gi|1743157285|ref|XM_003261343.3|
# E-value: 0.0
# Comprimento: 1466
# Identidade: 98.70395634379263 %
# Query cover: 41.754485901452576 %
# Positivies: 98.70395634379263 %
# Definição: PREDICTED: Nomascus leucogenys Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_024250382
# Hit id: gi|1351511102|ref|XM_024250382.1|
# E-value: 0.0
# Comprimento: 1466
# Identidade: 98.70395634379263 %
# Query cover: 41.754485901452576 %
# Positivies: 98.70395634379263 %
# Definição: PREDICTED: Pongo abelii Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: DQ534757
# Hit id: gi|106709181|gb|DQ534757.1|
# E-value: 0.0
# Comprimento: 1426
# Identidade: 99.78962131837307 %
# Query cover: 40.615209342067786 %
# Positivies: 99.78962131837307 %
# Definição: Homo sapiens Kruppel-like factor 14 (KLF14) mRNA, complete cds
# ---Alinhamento---- Query start: 1548 Sbjct start: 1447
#
# Acesso: DQ534757
# Hit id: gi|106709181|gb|DQ534757.1|
# E-value: 0.0
# Comprimento: 1112
# Identidade: 99.64028776978418 %
# Query cover: 31.67188835089718 %
# Positivies: 99.64028776978418 %
# Definição: Homo sapiens Kruppel-like factor 14 (KLF14) mRNA, complete cds
# ---Alinhamento---- Query start: 101 Sbjct start: 1
#
# Acesso: XM_047763546
# Hit id: gi|2225025468|ref|XM_047763546.1|
# E-value: 0.0
# Comprimento: 2204
# Identidade: 85.66243194192378 %
# Query cover: 62.77413842210196 %
# Positivies: 85.66243194192378 %
# Definição: PREDICTED: Phacochoerus africanus Krueppel-like factor 14 (LOC125117576), transcript variant X1, mRNA
# ---Alinhamento---- Query start: 5 Sbjct start: 84
#
# Acesso: XM_032753544
# Hit id: gi|1820543689|ref|XM_032753544.1|
# E-value: 0.0
# Comprimento: 1443
# Identidade: 98.54469854469855 %
# Query cover: 41.09940187980632 %
# Positivies: 98.54469854469855 %
# Definição: PREDICTED: Hylobates moloch Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 206 Sbjct start: 24
#
# Acesso: AF490374
# Hit id: gi|19919729|gb|AF490374.1|
# E-value: 0.0
# Comprimento: 1384
# Identidade: 99.63872832369943 %
# Query cover: 39.418968954713755 %
# Positivies: 99.63872832369943 %
# Definição: Homo sapiens BTEB5 mRNA, complete cds
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_035254713
# Hit id: gi|1864512387|ref|XM_035254713.1|
# E-value: 0.0
# Comprimento: 1597
# Identidade: 94.30181590482154 %
# Query cover: 45.485616633437765 %
# Positivies: 94.30181590482154 %
# Definição: PREDICTED: Callithrix jacchus Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 45 Sbjct start: 1
#
# Acesso: XM_025380901
# Hit id: gi|1411148840|ref|XM_025380901.1|
# E-value: 0.0
# Comprimento: 1466
# Identidade: 97.0668485675307 %
# Query cover: 41.754485901452576 %
# Positivies: 97.0668485675307 %
# Definição: PREDICTED: Theropithecus gelada Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_011723825
# Hit id: gi|795574486|ref|XM_011723825.1|
# E-value: 0.0
# Comprimento: 1466
# Identidade: 96.99863574351978 %
# Query cover: 41.754485901452576 %
# Positivies: 96.99863574351978 %
# Definição: PREDICTED: Macaca nemestrina Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_012473957
# Hit id: gi|1212357895|ref|XM_012473957.2|
# E-value: 0.0
# Comprimento: 1580
# Identidade: 94.43037974683544 %
# Query cover: 45.001424095699235 %
# Positivies: 94.43037974683544 %
# Definição: PREDICTED: Aotus nancymaae Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_049623634
# Hit id: gi|2277574273|ref|XM_049623634.1|
# E-value: 0.0
# Comprimento: 2115
# Identidade: 85.81560283687944 %
# Query cover: 60.239248077470805 %
# Positivies: 85.81560283687944 %
# Definição: PREDICTED: Panthera uncia Krueppel-like factor 14 (LOC125917433), mRNA >gi|2277576908|ref|XM_049624383.1| PREDICTED: Panthera uncia Krueppel-like factor 14 (LOC125918382), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_023207822
# Hit id: gi|1297629831|ref|XM_023207822.1|
# E-value: 0.0
# Comprimento: 1466
# Identidade: 96.79399727148704 %
# Query cover: 41.754485901452576 %
# Positivies: 96.79399727148704 %
# Definição: PREDICTED: Piliocolobus tephrosceles Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 175 Sbjct start: 1
#
# Acesso: XM_007469724
# Hit id: gi|602719230|ref|XM_007469724.1|
# E-value: 0.0
# Comprimento: 1973
# Identidade: 87.227572225038 %
# Query cover: 56.1948162916548 %
# Positivies: 87.227572225038 %
# Definição: PREDICTED: Lipotes vexillifer Kruppel-like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 2 Sbjct start: 104
#
# Acesso: XM_032643554
# Hit id: gi|1814742516|ref|XM_032643554.1|
# E-value: 0.0
# Comprimento: 1975
# Identidade: 87.0886075949367 %
# Query cover: 56.25178011962404 %
# Positivies: 87.0886075949367 %
# Definição: PREDICTED: Phocoena sinus Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 1 Sbjct start: 67
#
# Acesso: XM_022589472
# Hit id: gi|1246149598|ref|XM_022589472.1|
# E-value: 0.0
# Comprimento: 1971
# Identidade: 87.06240487062405 %
# Query cover: 56.137852463685554 %
# Positivies: 87.06240487062405 %
# Definição: PREDICTED: Delphinapterus leucas Kruppel like factor 14 (KLF14), mRNA
# ---Alinhamento---- Query start: 5 Sbjct start: 68
